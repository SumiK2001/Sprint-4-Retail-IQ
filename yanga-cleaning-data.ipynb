# %%
# DO NOT EDIT THIS CELL
import sqlite3
# %load_ext sql
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'
# %sql sqlite:///retailiq.db

# %% [markdown]
# # Cleaning Stores Dataset

# %%
# %sql select * from stores limit 5;

# %%
# %sql PRAGMA table_info(stores)

# %%
# %sql select COUNT(DISTINCT store_type) AS unique_stores from stores;

# %% [markdown]
# # Cleaning Sales Dataset

# %%
# %sql select * from sales limit 5;

# %%
# %sql PRAGMA table_info(sales)

# %%
#Checking for dates with slash, need to be fixed....
# %sql SELECT * FROM sales WHERE sale_date LIKE '%/%';

# %%
# %sql SELECT sale_date FROM sales LIMIT 20;

# %% [markdown]
# # Cleaning Sales Item Dataset

# %%
# %sql select * from sale_items limit 5;

# %%
# %sql select unit_price from sale_items where sale_id = 2

# %%
# %sql PRAGMA table_info(sale_items)

# %% [markdown]
# # Cleaning Employees Dataset

# %%
# %sql select * from employees limit 5;

# %%
# %sql PRAGMA table_info(employees)
