# %%
#pip install -U ipython-sql

# %%
import sqlite3
# %load_ext sql
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'
# %sql sqlite:///retailiq.db
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# # Cleaning Datasets

# %% [markdown]
# # Customers

# %%
# %sql select * from customers limit 20;
# Out:
#  * sqlite:///retailiq.db
# Done.
# [(1, 'Sipho Dlamini', 'Western Cape', 'Western Cape City C', 'Corporate', None, '2026-06-11'),
#  (2, 'Ayanda Botha', 'Eastern Cape', 'Eastern Cape City A', 'Retail', 61.0, '2025-01-09'),
#  (3, 'Anele Van Wyk', 'Free State', 'Free State City B', 'Retail', 82.0, '2026-05-10'),
#  (4, 'Kabelo Botha', 'Free State', None, 'Retail', 66.0, '2025-03-04'),
#  (5, 'Lerato Mokoena', 'KwaZulu-Natal', 'KwaZulu-Natal City C', 'Corporate', 68.0, '2025-10-22'),
#  (6, 'Kabelo Botha', 'Gauteng', 'Gauteng City C', 'Retail', 58.0, '2026-01-09'),
#  (7, 'Anele Jacobs', 'Western Cape ', 'Western Cape City A', 'Corporate', 24.0, '2025-12-15'),
#  (8, 'Noah Botha', 'Western Cape ', 'Western Cape City B', '  Corporate  ', 81.0, '2025-02-02'),
#  (9, 'Lerato Van Wyk', 'Free State', 'Free State City A', 'SME', 52.0, '2025-08-29'),
#  (10, 'Naledi Naidoo', 'Northern Cape', 'Northern Cape City C', 'Enterprise', 89.0, '2025-04-20'),
#  (11, 'Naledi Nkosi', 'Northern Cape', 'Northern Cape City A', 'Retail', 83.0, '2025-08-10'),
#  (12, 'Naledi Ndlovu', 'Limpopo', 'Limpopo City A', 'Corporate', 73.0, '2025-08-11'),
#  (13, 'Ayanda Van Wyk', '  Free State  ', 'Free State City B', 'Enterprise', 70.0, '2025/02/19'),
#  (14, 'Kabelo Naidoo', 'northern cape', 'Northern Cape City C', 'SME', 20.0, '2025-12-19'),
#  (15, 'Kabelo Botha', 'Western Cape', 'Western Cape City B', 'SME', 39.0, '2025-11-01'),
#  (16, 'Nomsa Naidoo', 'Free State', 'Free State City A', 'Enterprise', 37.0, '2025-07-02'),
#  (17, 'Liam Mthembu', 'Free State', 'Free State City B', 'Retail', 18.0, '2026-06-07'),
#  (18, 'Thabo Jacobs', 'Northern Cape', 'Northern Cape City A', 'Retail', 49.0, '2026-07-02'),
#  (19, 'Lerato Dlamini', 'Gauteng', 'Gauteng City C', 'Corporate', 37.0, '2025-08-16'),
#  (20, 'Noah Dlamini', 'Free State', 'Free State City B', 'Corporate', 62.0, '2025-10-09')]

# %%
# %sql pragma table_info(customers)
# Change date data type
# Out:
#  * sqlite:///retailiq.db
# Done.
# [(0, 'customer_id', 'INTEGER', 0, None, 0),
#  (1, 'customer_name', 'TEXT', 0, None, 0),
#  (2, 'province', 'TEXT', 0, None, 0),
#  (3, 'city', 'TEXT', 0, None, 0),
#  (4, 'customer_segment', 'TEXT', 0, None, 0),
#  (5, 'age', 'REAL', 0, None, 0),
#  (6, 'registration_date', 'TEXT', 0, None, 0)]

# %%
# %sql SELECT age FROM customers LIMIT 5;
# Out:
#  * sqlite:///retailiq.db
# Done.
# [(None,), (61.0,), (82.0,), (66.0,), (68.0,)]

# %%
# Change age to INT:
# %%sql ALTER TABLE customers
ALTER COLUMN age INT;
# Out:
#   Cell In[44], line 3
#     ALTER COLUMN age INT;
#           ^
# SyntaxError: invalid syntax
