# %%
# pip install -U ipython-sql

# %%
# DO NOT EDIT THIS CELL
import sqlite3
# %load_ext sql
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'
# %sql sqlite:///retailiq.db
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# # Cleaning Datasets

# %% [markdown]
# # Inventory

# %%
# %sql select * from inventory limit 20;
# Out:
#  * sqlite:///retailiq.db
# Done.
# [(1, 3653.0, 444.0, '1709', '169', '2025-07-06'),
#  (2, 9690.0, 196.0, '168', '427', '2025-07-06'),
#  (3, 10275.0, 391.0, '554', '399', '2025-02-25'),
#  (4, 8092.0, 254.0, '350', '216', '2025-09-22'),
#  (5, 15363.0, 415.0, '1751', '487', '2025-04-11'),
#  (6, None, 353.0, '1238', '11', '2026-02-21'),
#  (7, 17190.0, 178.0, '479', '461', '2026-06-19'),
#  (8, 19321.0, 254.0, '', '468', '2026-07-08'),
#  (9, 6904.0, 115.0, '1235', '240', '2026-04-06'),
#  (10, 13695.0, 321.0, '727', '142', '2025-10-09'),
#  (11, 7063.0, 291.0, '826', '341', '2025-01-12'),
#  (12, 216.0, 85.0, None, '96', '2025-10-09'),
#  (13, 4177.0, 25.0, '1191', '304', '2026-03-03'),
#  (14, 11250.0, 135.0, '117', '74', '2025-09-20'),
#  (15, 19366.0, 70.0, '367', '216', '2025-06-20'),
#  (16, 2920.0, 27.0, '631', '450', '2026-02-12'),
#  (17, 5826.0, 447.0, '1548', '475', '2026-02-11'),
#  (18, 4764.0, 35.0, '1003', '101', '2026-06-14'),
# ...

# %%
# %sql pragma table_info(inventory)
# Out:
#  * sqlite:///retailiq.db
# Done.
# [(0, 'inventory_id', 'INTEGER', 0, None, 0),
#  (1, 'product_id', 'REAL', 0, None, 0),
#  (2, 'store_id', 'REAL', 0, None, 0),
#  (3, 'stock_quantity', 'TEXT', 0, None, 0),
#  (4, 'reorder_level', 'TEXT', 0, None, 0),
#  (5, 'last_stock_update', 'TEXT', 0, None, 0)]
